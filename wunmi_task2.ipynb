# %% [markdown]
# for i in range(1 -50):
#     if i % 3 == 0 and i % 5 == 0:
#         print("FizzBuzz")
#     elif i % 3 == 0:
#         print("Fizz")
#     elif i % 5 == 0:
#         print("Buzz")
#     else:
#         print(i)
#
#
# def Area_Square(Length,number) :
#     Area_Square(Length *2)
#     return(L*2)
#     result= Area_Square(L*2)
#     Print(f"Area_Square:{result}")
#
#
# def average_number (*sum_numbers,average):
#     numbers = 1,2,3,4
#     count = 4
#     return 1+2+3+4/4
#     result=average_number(1+2+3+4/4)
#     print(f"the average is {result}")
